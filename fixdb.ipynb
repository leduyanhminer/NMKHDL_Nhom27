# %%
import csv

updates = []

with open('laptop_new2.csv', 'r') as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        try:
            ram = int(row["Memory (RAM)"])
        except ValueError:
            ram = None 
        try:
            screen_size = float(row["Screen size"])
        except ValueError:
            screen_size = None
        try:
            price = float(row["Price"])
        except ValueError:
            price = None

        update = {
            "_id": row["_id"],
            "Memory (RAM)": ram,
            "Screen size": screen_size,
            "Price": price
        }
        updates.append(update)

# %%
print(updates[5:10])
# Out:
# [{'_id': '6589cba38997406b55ed5eae', 'Memory (RAM)': 64, 'Screen size': 17.3, 'Price': 27119760.0}, {'_id': '6589cba38997406b55ed5eb5', 'Memory (RAM)': 16, 'Screen size': 15.6, 'Price': 35880000.0}, {'_id': '6589cba58997406b55ed5eb9', 'Memory (RAM)': 64, 'Screen size': 15.6, 'Price': 37416000.0}, {'_id': '6589cba58997406b55ed5eba', 'Memory (RAM)': 16, 'Screen size': 14.0, 'Price': 26399760.0}, {'_id': '6589cba58997406b55ed5ebc', 'Memory (RAM)': 16, 'Screen size': 15.6, 'Price': 19176000.0}]

# %%
from pymongo import MongoClient
from config import *
from bson import ObjectId

client = MongoClient(DB_URI)
db = client[DB_NAME]
collection = db[DB_COLLECTION_NAME]

for update in updates:
    collection.update_one(
        {'_id': ObjectId(update['_id'])},
        {'$set': {
            # 'Memory (RAM)': update['Memory (RAM)'],
            # 'Screen size': update['Screen size'],
            "Price": update["Price"]
        }}
    )

# %%
from bson import ObjectId
document_id = '6589cba38997406b55ed5eb5'
document = collection.find_one({'_id': ObjectId(document_id)})
document
# Out:
# {'_id': ObjectId('6589cba38997406b55ed5eb5'),
#  'Image': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x05\x05\x05\t\x06\t\t\t\t\x0c\x13\x0e\x0e\x0c\x0e\x0e\x19\x12\x0e\x12\x10\x17\x0e\x10\x10\x17\x10\x17\x17\x10\x14\x17\x14\x14\x1a\x17\x13\x13\x17\x1a\x14\x17\x18#\x18\x1c\x19\x1f\x1a\x18!\x18#\x18#""$\'(#\x17\'5\x01\t\t\x05\t\t\t\x0c\t\t\x13!\x17\x0e\x1a"\x1c\x0c\x18)"(\x1a"$""\x19,"(!"\x14#"\x1a\x1f\x1f\x1a\x1a\x1c\x18\x1c"\x1a$$#\x0e\x19$!\x17/\x19\x1a\x17"!\'\x1f\x17$*\xff\xc0\x00\x11\x08\x00\xa0\x00\xa0\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x9c\x00\x00\x02\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x07\x06\x08\x03\x04\x05\x02\t\x01\x10\x00\x02\x01\x03\x02\x03\x04\x05\x07\t\x07\x05\x01\x01\x00\x00\x01\x02\x03\x00\x04\x11\x05\x12\x06!1\x07\x13AQ\x14"2\x81\x92\x08\x18Bq\x91\x93\xd1\x15\x16ERUa\xa1\xd3\xe3#$3bt\xb1\xb36DS\xb2\xd2C\x82\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\